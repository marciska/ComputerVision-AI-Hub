# %% [markdown]
# # Diffusion Model
#
# Based on: https://www.youtube.com/watch?v=a4Yfz2FxXiY&ab_channel=DeepFindr
#
# Also useful:
#
# - x1...
# - x2...

# %% [markdown]
# ## Dataset

# %%
import torch
import torchvision
from torchvision.utils import make_grid
from torchvision.transforms import v2
import torchvision.transforms.functional as F
import matplotlib.pyplot as plt
import numpy as np

def show_images(dataset, num_samples=42, cols=6):
    """ Plots some samples from the dataset """
    plt.figure(figsize=(10,10)) 
    for i, img in enumerate(dataset):
        if i == num_samples:
            break
        ax = plt.subplot(int(num_samples/cols) + 1, cols, i + 1)
        ax.imshow(img[0])
        ax.set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

dataset = torchvision.datasets.Flowers102(root='./data', download=True,
    # transform=v2.Compose([
    #     v2.ToImage(),
    #     v2.ToDtype(torch.float32, scale=True)
    # ])
)
show_images(dataset)
